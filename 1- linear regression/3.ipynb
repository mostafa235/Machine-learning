# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('J:/Data science/ML/Pyhon for ML/3.1 UNZIP_ME_FOR_NOTEBOOKS_V4/DATA/Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# df.correlation()

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(16,6))

axes[0].plot(df['TV'],df['sales'],'o')
axes[0].set_ylabel("Sales" , c='y' , size=17)
axes[0].set_title("TV Spend", c='y', size=17)

axes[1].plot(df['radio'],df['sales'],'o')
axes[1].set_title("Radio Spend", c='y', size=17)
axes[1].set_ylabel("Sales", c='y', size=17)

axes[2].plot(df['newspaper'],df['sales'],'o')
axes[2].set_title("Newspaper Spend", c='y', size=17);
axes[2].set_ylabel("Sales", c='y', size=17)
plt.tight_layout();

# %%
x = df.drop('sales' , axis=1)
x.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y = df['sales']
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
x.shape , y.shape
# Out:
# ((200, 3), (200,))

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train ,y_test = train_test_split(x,y,test_size=.3 ,random_state=101)

# %%
len(df)
# Out:
# 200

# %%
print(len(x_train))
x_train.head()
# Out:
# 140
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8

# %%
print(len(x_train))
y_train.head()
# Out:
# 140
# 85     15.2
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
# Name: sales, dtype: float64

# %%
print(len(x_test))
x_test.head()
# Out:
# 60
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2

# %%
print(len(y_test))
y_test.head()
# Out:
# 60
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
# Name: sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test.head()
# Out:
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
# Name: sales, dtype: float64

# %%
model.predict(x_test)
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
y_prediction = model.predict(x_test)
y_prediction
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(y_test,y_prediction)
rmse
# Out:
# 37     3.834058
# 109    4.449719
# 31     3.449638
# 89     4.086563
# 66     3.082207
# 119    2.569047
# 54     4.494441
# 74     4.123106
# 145    3.209361
# 142    4.483302
# 148    3.301515
# 112    3.754997
# 174    3.391165
# 55     4.868265
# 141    4.381780
# 149    3.178050
# 25     3.464102
# 34     3.082207
# 170    2.898275
# 39     4.636809
# 172    2.756810
# 153    4.358899
# 175    5.196152
# 61     4.919350
# 65     3.049590
# 50     3.376389
# 42     4.549725
# 129    3.114482
# 179    3.549648
# 2      3.049590
# 12     3.033150
# 133    4.427189
# 90     3.346640
# 22     2.366432
# 41     4.135215
# 32     3.098387
# 125    3.255764
# 196    3.114482
# 158    2.701851
# 180    3.240370
# 16     3.535534
# 186    3.209361
# 144    3.376389
# 121    2.645751
# 80     3.435113
# 18     3.361547
# 78     2.302173
# 48     3.847077
# 4      3.591657
# 15     4.732864
# 1      3.224903
# 43     3.591657
# 102    3.847077
# 164    3.449638
# 9      3.255764
# ...
